# %%
#print Hi in doble quotes
print("Hi")
# Out:
# Hi

# %%
#print hi in single quotes
print('hi')
# Out:
# hi

# %%
#print hello start with single quote and end with double quote - we ger syntax error
print('hello")
# Out:
#   File <command-4769579733612876>, line 2
#     print('hello")
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#print This is Rama's bag using special character[apostrophe (')] in Rams's name in double quotes
print("This is Rama's bag")
print('This is Rama"s bag')
# Out:
# This is Rama's bag
# This is Rama"s bag

# %%
#print This is Rama's bag using special character[apostrophe (')] in Rams's name in single quotes - error
print('This is Rama's bag')
# Out:
#   File <command-4769579733612878>, line 2
#     print('This is Rama's bag')
#                              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#escape character
print("This is Rama\'s bag")
#print This is Rama's bag using special character[apostrophe (')] in Rams's name in single quotes
print('This is Rama\'s bag')
print("This is Rama\"s bag")
#
# Out:
# This is Rama's bag
# This is Rama's bag
# This is Rama"s bag

# %%
a=10
print (a)
print('a')
# Out:
# 10
# a

# %%
# int example 
# #checking the (a) type-result 10 is integer (int) from previous example
type(a)
# Out:
# int

# %%
#string example
t='rama'
type(t)
# Out:
# str

# %%
#float example
f=10.5
type(f)
# Out:
# float

# %%
a=10
b=20
c=a+b
print(c)
type(c)
# Out:
# 30
# int

# %%
a=12.3
b=56.7
c=a+b
print(c)
type(c)
d=a*b
print(d)
type(d)
# Out:
# 69.0
# 697.4100000000001
# float

# %%
stid=input("enter your student id: ")
stname=input("enter your student name: ")
m1=input("enter your m1 marks: ")
m2=input("enter your m2 marks: ")
m3=input("enter your m3 marks: ")
tot_marks=int(m1)+int(m2)+int(m3)
print(tot_marks)
# Out:
# enter your student id:  5623
# enter your student name:  Ravi
# enter your m1 marks:  96
# enter your m2 marks:  98
# enter your m3 marks:  85
# 279

# %%
stid=input("enter your student id: ")
stname=input("enter your student name: ")
Mt=input("enter your m1 marks: ")
Sc=input("enter your m2 marks: ")
Sl=input("enter your m3 marks: ")

print("my id ",stid)
print("my name ",stname)
print("my marks Mathematics ",Mt)
print("my marks Science ",Sc)
print("my marks Social ",Sl)

tot_marks=int(Maths)+int(Science)+int(Social)
print(tot_marks)
# Out:
# enter your student id:  2356
# enter your student name:  Babu
# enter your m1 marks:  98
# enter your m2 marks:  96
# enter your m3 marks:  89
# my id  2356
# my name  Babu
# my marks Mathematics  98
# my marks Science  96
# my marks Social  89
# 289

# %%
topics covered day 1:
    what is python
    why python
   
    features of python: easy, read, portable, stand libraries, third party libraries, open source, versatile app, dynamic typing, extensable
   
    develop: web app, mobile app, gaming app, data engineer, ML, DS
    
    installation
    
    commands: print("")
    print('')
    print("""  """)
    print('''  ''')
    
    escape character
    type of data
    input (): by default the datatype will be str
    typecast  --> chanf=ging the data type 
    int(a)

    where we have executed python code:
        command prompt
        idle
        python window

    created a file  --> saved it  --> executed in two places
        1. idle --> go to that file  --> click on run  --> run module
        2. commapnd prompt : python <location, filename.py>
        py <location, filename.py>
